# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv('IMDB-Movie-Data.csv')
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.columns=df.columns.str.lower()
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.genre=='Action'
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: genre, Length: 1000, dtype: bool

# %%
df[df.genre=='Action']
# Out:
#      rank                 title   genre  \
# 123   124  Boyka: Undisputed IV  Action
# 580   581  Kickboxer: Vengeance  Action
#
#                                            description         director  \
# 123  In the fourth installment of the fighting fran...  Todor Chapkanov
# 580         A kick boxer is out to avenge his brother.   John Stockwell
#
#                                                 actors  year  \
# 123  Scott Adkins, Teodora Duhovnikova, Alon Aboutb...  2016
# 580  Dave Bautista, Alain Moussi, Gina Carano, Jean...  2016
#
#      runtime (minutes)  rating  votes  revenue (millions)  metascore
# 123                 86     7.4  10428                 NaN        NaN
# 580                 90     4.9   6809              131.56       37.0

# %%
df.genre.str.contains('Action')
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: genre, Length: 1000, dtype: bool

# %%
df[df.genre.str.contains('Action')]
# Out:
#      rank                           title                       genre  \
# 0       1         Guardians of the Galaxy     Action,Adventure,Sci-Fi
# 4       5                   Suicide Squad    Action,Adventure,Fantasy
# 5       6                  The Great Wall    Action,Adventure,Fantasy
# 8       9              The Lost City of Z  Action,Adventure,Biography
# 12     13                       Rogue One     Action,Adventure,Sci-Fi
# ..    ...                             ...                         ...
# 958   959                  3 Days to Kill       Action,Drama,Thriller
# 968   969                         Wrecker      Action,Horror,Thriller
# 969   970                 The Lone Ranger    Action,Adventure,Western
# 990   991  Underworld: Rise of the Lycans    Action,Adventure,Fantasy
# 993   994        Resident Evil: Afterlife     Action,Adventure,Horror
#
#                                            description            director  \
# ...

# %%
len(df[df.genre.str.contains('Action')])
# Out:
# 303

# %%
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.actors.str.contains('Will Smith')
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Name: actors, Length: 1000, dtype: bool

# %%
df[df.actors.str.contains('Will Smith')]
# Out:
#      rank                     title                     genre  \
# 4       5             Suicide Squad  Action,Adventure,Fantasy
# 73     74         Collateral Beauty             Drama,Romance
# 488   489                     Focus        Comedy,Crime,Drama
# 495   496               I Am Legend       Drama,Horror,Sci-Fi
# 496   497            Men in Black 3   Action,Adventure,Comedy
# 640   641  The Pursuit of Happyness           Biography,Drama
# 684   685              Seven Pounds             Drama,Romance
# 789   790                   Hancock        Action,Crime,Drama
# 896   897                Concussion     Biography,Drama,Sport
# 948   949               After Earth   Action,Adventure,Sci-Fi
#
#                                            description            director  \
# 4    A secret government agency recruits some of th...          David Ayer
# 73   Retreating from life after a tragedy, a man qu...       David Frankel
# ...

# %%
len(df[df.actors.str.contains('Will Smith')])
# Out:
# 10

# %%
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
a=np.random.randint(1,10,size=(3,3))
df2=pd.DataFrame(a,columns=list('abc'))
df2
# Out:
#    a  b  c
# 0  5  5  2
# 1  6  7  4
# 2  6  8  8

# %%
df2.apply(np.sum)
# Out:
# a    17
# b    20
# c    14
# dtype: int64

# %%
df2.apply(np.sum,axis=1)
# Out:
# 0    12
# 1    17
# 2    22
# dtype: int64

# %%
df2['a'].apply(np.sum)
# Out:
# 0    5
# 1    6
# 2    6
# Name: a, dtype: int32

# %%
#lambda function

# %%
def add100(p):
    return p+100

# %%
df2['a'].apply(add100)
# Out:
# 0    105
# 1    106
# 2    106
# Name: a, dtype: int64

# %%
df.actors.str.split(',')
# Out:
# 0      [Chris Pratt,  Vin Diesel,  Bradley Cooper,  Z...
# 1      [Noomi Rapace,  Logan Marshall-Green,  Michael...
# 2      [James McAvoy,  Anya Taylor-Joy,  Haley Lu Ric...
# 3      [Matthew McConaughey, Reese Witherspoon,  Seth...
# 4      [Will Smith,  Jared Leto,  Margot Robbie,  Vio...
#                              ...
# 995    [Chiwetel Ejiofor,  Nicole Kidman,  Julia Robe...
# 996    [Lauren German,  Heather Matarazzo,  Bijou Phi...
# 997    [Robert Hoffman,  Briana Evigan,  Cassie Ventu...
# 998    [Adam Pally,  T.J. Miller,  Thomas Middleditch...
# 999    [Kevin Spacey,  Jennifer Garner,  Robbie Amell...
# Name: actors, Length: 1000, dtype: object

# %%
h=lambda p:p+500

# %%
df2['a'].apply(h)
# Out:
# 0    505
# 1    506
# 2    506
# Name: a, dtype: int64

# %%
df2['a'].apply(lambda p:p+600)
# Out:
# 0    605
# 1    606
# 2    606
# Name: a, dtype: int64

# %%
df.actors.str.split(',').apply(lambda p:p[0])
# Out:
# 0              Chris Pratt
# 1             Noomi Rapace
# 2             James McAvoy
# 3      Matthew McConaughey
# 4               Will Smith
#               ...
# 995       Chiwetel Ejiofor
# 996          Lauren German
# 997         Robert Hoffman
# 998             Adam Pally
# 999           Kevin Spacey
# Name: actors, Length: 1000, dtype: object

# %%
df.actors.str.split(',').apply(lambda p:p[1])
# Out:
# 0                 Vin Diesel
# 1       Logan Marshall-Green
# 2            Anya Taylor-Joy
# 3          Reese Witherspoon
# 4                 Jared Leto
#                ...
# 995            Nicole Kidman
# 996        Heather Matarazzo
# 997            Briana Evigan
# 998              T.J. Miller
# 999          Jennifer Garner
# Name: actors, Length: 1000, dtype: object

# %%
df.actors.str.split(',').apply(lambda p:p[2])
# Out:
# 0            Bradley Cooper
# 1        Michael Fassbender
# 2       Haley Lu Richardson
# 3           Seth MacFarlane
# 4             Margot Robbie
#                ...
# 995           Julia Roberts
# 996          Bijou Phillips
# 997          Cassie Ventura
# 998      Thomas Middleditch
# 999            Robbie Amell
# Name: actors, Length: 1000, dtype: object

# %%
df.genre.str.split(',')
# Out:
# 0       [Action, Adventure, Sci-Fi]
# 1      [Adventure, Mystery, Sci-Fi]
# 2                [Horror, Thriller]
# 3       [Animation, Comedy, Family]
# 4      [Action, Adventure, Fantasy]
#                    ...
# 995         [Crime, Drama, Mystery]
# 996                        [Horror]
# 997         [Drama, Music, Romance]
# 998             [Adventure, Comedy]
# 999       [Comedy, Family, Fantasy]
# Name: genre, Length: 1000, dtype: object

# %%
df.genre.str.split(',').apply(lambda p:p[0])
# Out:
# 0         Action
# 1      Adventure
# 2         Horror
# 3      Animation
# 4         Action
#          ...
# 995        Crime
# 996       Horror
# 997        Drama
# 998    Adventure
# 999       Comedy
# Name: genre, Length: 1000, dtype: object

# %%
df.genre.str.split(',').apply(lambda p:p[0].upper())
# Out:
# 0         ACTION
# 1      ADVENTURE
# 2         HORROR
# 3      ANIMATION
# 4         ACTION
#          ...
# 995        CRIME
# 996       HORROR
# 997        DRAMA
# 998    ADVENTURE
# 999       COMEDY
# Name: genre, Length: 1000, dtype: object

# %%
df['main_genre']=df.genre.str.split(',').apply(lambda p:p[0].upper())
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df['lead_actor']=df.actors.str.split(',').apply(lambda p:p[0])
df
# Out:
#      rank                    title                     genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            description              director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df=pd.read_csv('j:/data_science/csv/ipl/matches.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df[df.city=='Bangalore']
# Out:
#           id       city        date  player_of_match                  venue  \
# 0     335982  Bangalore  2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  Bangalore  2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  Bangalore  2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  Bangalore  2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  Bangalore  2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...         ...              ...                    ...
# 606  1082621  Bangalore  2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  Bangalore  2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  Bangalore  2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  Bangalore  2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  Bangalore  2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
df.loc[df.city=='Bangalore','city']='bangalore'
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df[df.city=='bangalore']
# Out:
#           id       city        date  player_of_match                  venue  \
# 0     335982  bangalore  2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  bangalore  2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  bangalore  2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  bangalore  2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  bangalore  2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...        ...         ...              ...                    ...
# 606  1082621  bangalore  2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  bangalore  2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  bangalore  2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  bangalore  2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  bangalore  2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
# ...

# %%
df.loc[df.city=='bangalore','city']='mycity'
df
# Out:
#           id        city        date player_of_match  \
# 0     335982      mycity  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
df[df.city=='mycity']
# Out:
#           id    city        date  player_of_match                  venue  \
# 0     335982  mycity  2008-04-18      BB McCullum  M Chinnaswamy Stadium
# 10    335992  mycity  2008-04-26        SR Watson  M Chinnaswamy Stadium
# 14    335996  mycity  2008-04-28         MS Dhoni  M Chinnaswamy Stadium
# 24    336006  mycity  2008-05-05      S Sreesanth  M Chinnaswamy Stadium
# 30    336012  mycity  2008-05-28     CRD Fernando  M Chinnaswamy Stadium
# ..       ...     ...         ...              ...                    ...
# 606  1082621  mycity  2017-04-27           AJ Tye  M Chinnaswamy Stadium
# 618  1082633  mycity  2017-05-05   Sandeep Sharma  M Chinnaswamy Stadium
# 621  1082636  mycity  2017-05-07        SP Narine  M Chinnaswamy Stadium
# 633  1082648  mycity  2017-05-17  NM Coulter-Nile  M Chinnaswamy Stadium
# 634  1082649  mycity  2017-05-19        KV Sharma  M Chinnaswamy Stadium
#
#      neutral_venue                        team1                  team2  \
# ...

# %%
df=pd.read_csv('j:/data_science/csv/ipl/matches.csv')
df
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %%
filt=(df.team1.isin(['Royal Challengers Bangalore','Kolkata Knight Riders'])  )   & ( df.team2.isin(['Royal Challengers Bangalore','Kolkata Knight Riders']) )
filt
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# Length: 816, dtype: bool

# %%
df[filt]
# Out:
#           id       city        date  player_of_match  \
# 0     335982  Bangalore  2008-04-18      BB McCullum
# 28    336010    Kolkata  2008-05-08       SC Ganguly
# 74    392199     Durban  2009-04-29       MV Boucher
# 96    392221  Centurion  2009-05-12      LRPL Taylor
# 118   419109    Kolkata  2010-03-14        MK Tiwary
# 157   419148  Bangalore  2010-04-10    R Vinay Kumar
# 198   501222    Kolkata  2011-04-22         CH Gayle
# 231   501255  Bangalore  2011-05-14         CH Gayle
# 257   548315  Bangalore  2012-04-10         L Balaji
# 284   548344    Kolkata  2012-04-28        G Gambhir
# 332   598008  Bangalore  2013-04-11         CH Gayle
# 381   598057     Ranchi  2013-05-12        JH Kallis
# 408   729299        NaN  2014-04-24          CA Lynn
# 446   734027    Kolkata  2014-05-22       RV Uthappa
# 462   829713    Kolkata  2015-04-11         CH Gayle
# 490   829771  Bangalore  2015-05-02    Mandeep Singh
# 546   980959  Bangalore  2016-05-02       AD Russell
# ...

# %%
len(df[filt])
# Out:
# 26

# %%
filter2=df.winner=='Kolkata Knight Riders'
filter2
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 811    False
# 812    False
# 813    False
# 814    False
# 815    False
# Name: winner, Length: 816, dtype: bool

# %%
df[filt & filter2]
# Out:
#           id       city        date  player_of_match  \
# 0     335982  Bangalore  2008-04-18      BB McCullum
# 28    336010    Kolkata  2008-05-08       SC Ganguly
# 118   419109    Kolkata  2010-03-14        MK Tiwary
# 257   548315  Bangalore  2012-04-10         L Balaji
# 284   548344    Kolkata  2012-04-28        G Gambhir
# 381   598057     Ranchi  2013-05-12        JH Kallis
# 408   729299        NaN  2014-04-24          CA Lynn
# 446   734027    Kolkata  2014-05-22       RV Uthappa
# 546   980959  Bangalore  2016-05-02       AD Russell
# 603  1082617    Kolkata  2017-04-23  NM Coulter-Nile
# 621  1082636  Bangalore  2017-05-07        SP Narine
# 638  1136563    Kolkata  2018-04-08        SP Narine
# 664  1136589  Bengaluru  2018-04-29          CA Lynn
# 712  1175372  Bengaluru  2019-04-05       AD Russell
#
#                                   venue  neutral_venue  \
# 0                 M Chinnaswamy Stadium              0
# ...

# %%
len(df[filt & filter2])
# Out:
# 14

# %%
df.city.value_counts()
# Out:
# city
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          65
# Hyderabad          64
# Chennai            57
# Chandigarh         56
# Jaipur             47
# Pune               38
# Abu Dhabi          29
# Dubai              26
# Bengaluru          15
# Durban             15
# Visakhapatnam      13
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Rajkot             10
# Dharamsala          9
# Indore              9
# Johannesburg        8
# Cuttack             7
# Cape Town           7
# Port Elizabeth      7
# Ranchi              7
# Raipur              6
# Kochi               5
# Kanpur              4
# East London         3
# Kimberley           3
# Nagpur              3
# Bloemfontein        2
# Name: count, dtype: int64

# %%
df.city.value_counts(ascending=True)
# Out:
# city
# Bloemfontein        2
# Nagpur              3
# East London         3
# Kimberley           3
# Kanpur              4
# Kochi               5
# Raipur              6
# Ranchi              7
# Cape Town           7
# Port Elizabeth      7
# Cuttack             7
# Johannesburg        8
# Indore              9
# Dharamsala          9
# Rajkot             10
# Ahmedabad          12
# Sharjah            12
# Centurion          12
# Visakhapatnam      13
# Durban             15
# Bengaluru          15
# Dubai              26
# Abu Dhabi          29
# Pune               38
# Jaipur             47
# Chandigarh         56
# Chennai            57
# Hyderabad          64
# Bangalore          65
# Delhi              74
# Kolkata            77
# Mumbai            101
# Name: count, dtype: int64

# %%
df.city.value_counts(normalize=True)
# Out:
# city
# Mumbai            0.125778
# Kolkata           0.095890
# Delhi             0.092154
# Bangalore         0.080946
# Hyderabad         0.079701
# Chennai           0.070984
# Chandigarh        0.069738
# Jaipur            0.058531
# Pune              0.047323
# Abu Dhabi         0.036115
# Dubai             0.032379
# Bengaluru         0.018680
# Durban            0.018680
# Visakhapatnam     0.016189
# Ahmedabad         0.014944
# Sharjah           0.014944
# Centurion         0.014944
# Rajkot            0.012453
# Dharamsala        0.011208
# Indore            0.011208
# Johannesburg      0.009963
# Cuttack           0.008717
# Cape Town         0.008717
# Port Elizabeth    0.008717
# Ranchi            0.008717
# Raipur            0.007472
# Kochi             0.006227
# Kanpur            0.004981
# East London       0.003736
# Kimberley         0.003736
# Nagpur            0.003736
# Bloemfontein      0.002491
# Name: proportion, dtype: float64

# %%
df.city.value_counts(normalize=True)['Kolkata']
# Out:
# 0.0958904109589041

# %%
df=pd.read_csv('usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df[df.model=='SEL']
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# 12   2011   SEL  16950     9388   Green         AUTO
# 16   2010   SEL  15999    19926  Silver         AUTO
# 18   2011   SEL  15992    11662    Blue         AUTO
# 19   2011   SEL  15992    32069  Silver         AUTO
# 21   2010   SEL  15980    39943   White         AUTO
# 23   2010   SEL  15889    24920   Black         AUTO
# 24   2009   SEL  15688    20019    Blue         AUTO
# 29   2009   SEL  14999    33107  Silver         AUTO
# 33   2011   SEL  14992    18948   Black         AUTO
# 35   2010   SEL  14990    33036   Black         AUTO
# ...

# %%
df[df.model=='SEL'].price.sum()
# Out:
# 370513

# %%
df[df.model=='SES'].price.sum()
# Out:
# 622011

# %%
df[df.model=='SE'].price.sum()
# Out:
# 951766

# %%
df.groupby('model')

# %%
#aggregate function : that works on multiple rows

# %%
df.groupby('model').sum()
# Out:
#          year   price  mileage  \
# model
# SE     156663  951766  3630219
# SEL     46232  370513   603495
# SES     98414  622011  2405383
#
#                                                    color  \
# model
# SE     WhiteWhiteSilverBlueBlackBlackBlackBlackWhiteS...
# SEL    YellowGraySilverGraySilverBlueSilverGreenSilve...
# SES    SilverSilverBlackSilverRedBlueSilverSilverGray...
#
#                                             transmission
# model
# SE     AUTOAUTOAUTOAUTOAUTOAUTOMANUALAUTOAUTOAUTOAUTO...
# SEL    AUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAUTOAU...
# SES    AUTOAUTOAUTOAUTOAUTOAUTOAUTOMANUALAUTOAUTOAUTO...

# %%
df.groupby('model').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File F:\anaconda\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File F:\anaconda\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File F:\anaconda\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# ...

# %%
df.groupby('model').sum()['price']
# Out:
# model
# SE     951766
# SEL    370513
# SES    622011
# Name: price, dtype: int64

# %%
df.groupby('model')['price'].sum()
# Out:
# model
# SE     951766
# SEL    370513
# SES    622011
# Name: price, dtype: int64

# %%
df.groupby('model')['price'].mean()
# Out:
# model
# SE     12202.128205
# SEL    16109.260870
# SES    12694.102041
# Name: price, dtype: float64

# %%
df.groupby('model')['price'].max()
# Out:
# model
# SE     17500
# SEL    21992
# SES    16995
# Name: price, dtype: int64

# %%
df.groupby('model')['price'].min()
# Out:
# model
# SE      3800
# SEL    10995
# SES     6200
# Name: price, dtype: int64

# %%
df.groupby('model')[['price','mileage']].sum()
# Out:
#         price  mileage
# model
# SE     951766  3630219
# SEL    370513   603495
# SES    622011  2405383

# %%
df.groupby('model')[['price','mileage']].agg(['sum','mean','max','min'])
# Out:
#         price                              mileage
#           sum          mean    max    min      sum          mean     max   min
# model
# SE     951766  12202.128205  17500   3800  3630219  46541.269231  151479  4867
# SEL    370513  16109.260870  21992  10995   603495  26238.913043   78264  7351
# SES    622011  12694.102041  16995   6200  2405383  49089.448980  119720  9199

# %%
df.groupby('model').agg({'price':'sum','mileage':'mean'})
# Out:
#         price       mileage
# model
# SE     951766  46541.269231
# SEL    370513  26238.913043
# SES    622011  49089.448980

# %%
df[df.model=='SE'].price.sum()
# Out:
# 951766

# %%
df.groupby(['model','color']).price.sum()
# Out:
# model  color
# SE     Black     253559
#        Blue      118768
#        Gold       10955
#        Gray       89716
#        Green      43600
#        Red       129949
#        Silver    125893
#        White     174427
#        Yellow      4899
# SEL    Black      45871
#        Blue       48680
#        Gray       77963
#        Green      16950
#        Red        27939
#        Silver    115138
#        White      15980
#        Yellow     21992
# SES    Black     166589
#        Blue       65292
#        Gray       50969
#        Red       128582
#        Silver    194680
#        White       7900
#        Yellow      7999
# Name: price, dtype: int64

# %%
df.groupby(['model','color','transmission']).price.sum()
# Out:
# model  color   transmission
# SE     Black   AUTO            172808
#                MANUAL           80751
#        Blue    AUTO            118768
#        Gold    AUTO             10955
#        Gray    AUTO             89716
#        Green   AUTO             32764
#                MANUAL           10836
#        Red     AUTO            118499
#                MANUAL           11450
#        Silver  AUTO             92136
#                MANUAL           33757
#        White   AUTO            127952
#                MANUAL           46475
#        Yellow  AUTO              4899
# SEL    Black   AUTO             45871
#        Blue    AUTO             48680
#        Gray    AUTO             63486
#                MANUAL           14477
#        Green   AUTO             16950
#        Red     AUTO             27939
#        Silver  AUTO            115138
#        White   AUTO             15980
#        Yellow  AUTO             21992
# SES    Black   AUTO            133918
# ...
