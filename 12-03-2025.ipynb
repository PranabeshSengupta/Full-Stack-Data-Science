# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
df=pd.read_csv('j:/data_science/csv/classification8.csv')
df
# Out:
#    salary  purchase
# 0    1000         1
# 1    2000         1
# 2    3000         1
# 3    4000         0
# 4    5000         0
# 5    6000         1
# 6    7000         1
# 7    8000         1
# 8    9000         1
# 9   10000         1

# %%
X=df[['salary']]
y=df.purchase

# %%
model=DecisionTreeClassifier(criterion='entropy')

# %%
model.fit(X,y)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(model)
# Out:
# [Text(0.6, 0.8333333333333334, 'x[0] <= 5500.0\nentropy = 0.722\nsamples = 10\nvalue = [2, 8]'),
#  Text(0.4, 0.5, 'x[0] <= 3500.0\nentropy = 0.971\nsamples = 5\nvalue = [2, 3]'),
#  Text(0.5, 0.6666666666666667, 'True  '),
#  Text(0.2, 0.16666666666666666, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(0.6, 0.16666666666666666, 'entropy = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(0.8, 0.5, 'entropy = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.7, 0.6666666666666667, '  False')]

# %%
model.score(X,y)
# Out:
# 1.0
