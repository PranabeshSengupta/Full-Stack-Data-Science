# %%
import numpy as np
import pandas as pd

# %%
#Updating value of a single cell

# %%
df=pd.read_csv('usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.loc[0,'price']
# Out:
# 21992

# %%
df.loc[0,'price']=100
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL    100     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.loc[0]
# Out:
# year              2011
# model              SEL
# price              100
# mileage           7413
# color           Yellow
# transmission      AUTO
# Name: 0, dtype: object

# %%
df.loc[0,['year',	'model',	'price']]
# Out:
# year     2011
# model     SEL
# price     100
# Name: 0, dtype: object

# %%
df.loc[0,['year',	'model',	'price']]=[200,300,400]
df
# Out:
#      year model  price  mileage   color transmission
# 0     200   300    400     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.loc[0,['year',	'model',	'price']]=[200,300]
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df.loc[0,['year',	'model',	'price']]=[200,300]
#       2 df
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexing.py:911, in _LocationIndexer.__setitem__(self, key, value)
#     908 self._has_valid_setitem_indexer(key)
#     910 iloc = self if self.name == "iloc" else self.obj.iloc
# --> 911 iloc._setitem_with_indexer(indexer, value, self.name)
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexing.py:1942, in _iLocIndexer._setitem_with_indexer(self, indexer, value, name)
#    1939 # align and set the values
#    1940 if take_split_path:
#    1941     # We have to operate column-wise
# -> 1942     self._setitem_with_indexer_split_path(indexer, value, name)
#    1943 else:
#    1944     self._setitem_single_block(indexer, value, name)
#
# ...

# %%
df.loc[:2,['year',	'model',	'price']]=np.random.randint(1000,2000,size=(3,3))
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#dropping rows and columns

# %%
df.drop(0)
# Out:
#      year model  price  mileage   color transmission
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [149 rows x 6 columns]

# %%
df.drop(3)
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [149 rows x 6 columns]

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.drop([1,3,4])
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [147 rows x 6 columns]

# %%
df.drop(range(1,101))
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 101  2009    SE  12280    29288     Red         AUTO
# 102  2009    SE  11999    36124    Blue         AUTO
# 103  2009    SE  11992    32559   Black       MANUAL
# 104  2009   SES  11984    59048   Black         AUTO
# 105  2009    SE  11980    55170     Red         AUTO
# 106  2010    SE  11792    39722   Green         AUTO
# 107  2008    SE  11754    38286   Black         AUTO
# 108  2008   SES  11749    57341     Red         AUTO
# 109  2008   SES  11495    82221  Silver         AUTO
# 110  2008    SE  11450    85229     Red       MANUAL
# 111  2009   SES  10995    42834     Red         AUTO
# 112  2005   SES  10995    69415    Blue         AUTO
# 113  2009   SEL  10995    78264    Gray         AUTO
# 114  2009    SE  10979    60709     Red         AUTO
# 115  2008    SE  10955    39643    Gray         AUTO
# 116  2009    SE  10955    40180    Gold         AUTO
# ...

# %%
df.drop('price',axis=1)
# Out:
#      year model  mileage   color transmission
# 0    1887  1277     7413  Yellow         AUTO
# 1    1439  1688    10926    Gray         AUTO
# 2    1955  1864     7351  Silver         AUTO
# 3    2011   SEL    11613    Gray         AUTO
# 4    2012    SE     8367   White         AUTO
# ..    ...   ...      ...     ...          ...
# 145  2006   SES    95000  Silver         AUTO
# 146  2002    SE    87003     Red         AUTO
# 147  2000    SE    96841     Red         AUTO
# 148  2001    SE   151479  Yellow         AUTO
# 149  2000    SE   109259     Red         AUTO
#
# [150 rows x 5 columns]

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.drop(columns='price')
# Out:
#      year model  mileage   color transmission
# 0    1887  1277     7413  Yellow         AUTO
# 1    1439  1688    10926    Gray         AUTO
# 2    1955  1864     7351  Silver         AUTO
# 3    2011   SEL    11613    Gray         AUTO
# 4    2012    SE     8367   White         AUTO
# ..    ...   ...      ...     ...          ...
# 145  2006   SES    95000  Silver         AUTO
# 146  2002    SE    87003     Red         AUTO
# 147  2000    SE    96841     Red         AUTO
# 148  2001    SE   151479  Yellow         AUTO
# 149  2000    SE   109259     Red         AUTO
#
# [150 rows x 5 columns]

# %%
df.drop(columns=['year',	'model',	'mileage'])
# Out:
#      price   color transmission
# 0     1854  Yellow         AUTO
# 1     1780    Gray         AUTO
# 2     1830  Silver         AUTO
# 3    17809    Gray         AUTO
# 4    17500   White         AUTO
# ..     ...     ...          ...
# 145   6200  Silver         AUTO
# 146   5995     Red         AUTO
# 147   5980     Red         AUTO
# 148   4899  Yellow         AUTO
# 149   3800     Red         AUTO
#
# [150 rows x 3 columns]

# %%
#changing row and column labels

# %%
#changing row index all values

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.index=np.random.randint(100,400,size=150)
df
# Out:
#      year model  price  mileage   color transmission
# 305  1887  1277   1854     7413  Yellow         AUTO
# 206  1439  1688   1780    10926    Gray         AUTO
# 297  1955  1864   1830     7351  Silver         AUTO
# 287  2011   SEL  17809    11613    Gray         AUTO
# 342  2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 380  2006   SES   6200    95000  Silver         AUTO
# 311  2002    SE   5995    87003     Red         AUTO
# 192  2000    SE   5980    96841     Red         AUTO
# 316  2001    SE   4899   151479  Yellow         AUTO
# 391  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.index=range(300,450)
df
# Out:
#      year model  price  mileage   color transmission
# 300  1887  1277   1854     7413  Yellow         AUTO
# 301  1439  1688   1780    10926    Gray         AUTO
# 302  1955  1864   1830     7351  Silver         AUTO
# 303  2011   SEL  17809    11613    Gray         AUTO
# 304  2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 445  2006   SES   6200    95000  Silver         AUTO
# 446  2002    SE   5995    87003     Red         AUTO
# 447  2000    SE   5980    96841     Red         AUTO
# 448  2001    SE   4899   151479  Yellow         AUTO
# 449  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#changing columns

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
df.columns=list('abcdef')
df
# Out:
#         a     b      c       d       e     f
# 300  1887  1277   1854    7413  Yellow  AUTO
# 301  1439  1688   1780   10926    Gray  AUTO
# 302  1955  1864   1830    7351  Silver  AUTO
# 303  2011   SEL  17809   11613    Gray  AUTO
# 304  2012    SE  17500    8367   White  AUTO
# ..    ...   ...    ...     ...     ...   ...
# 445  2006   SES   6200   95000  Silver  AUTO
# 446  2002    SE   5995   87003     Red  AUTO
# 447  2000    SE   5980   96841     Red  AUTO
# 448  2001    SE   4899  151479  Yellow  AUTO
# 449  2000    SE   3800  109259     Red  AUTO
#
# [150 rows x 6 columns]

# %%
df.columns=['year', 'model', 'price', 'mileage', 'color', 'transmission']
df
# Out:
#      year model  price  mileage   color transmission
# 300  1887  1277   1854     7413  Yellow         AUTO
# 301  1439  1688   1780    10926    Gray         AUTO
# 302  1955  1864   1830     7351  Silver         AUTO
# 303  2011   SEL  17809    11613    Gray         AUTO
# 304  2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 445  2006   SES   6200    95000  Silver         AUTO
# 446  2002    SE   5995    87003     Red         AUTO
# 447  2000    SE   5980    96841     Red         AUTO
# 448  2001    SE   4899   151479  Yellow         AUTO
# 449  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#rename row index /column labels

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 300  1887  1277   1854     7413  Yellow         AUTO
# 301  1439  1688   1780    10926    Gray         AUTO
# 302  1955  1864   1830     7351  Silver         AUTO
# 303  2011   SEL  17809    11613    Gray         AUTO
# 304  2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 445  2006   SES   6200    95000  Silver         AUTO
# 446  2002    SE   5995    87003     Red         AUTO
# 447  2000    SE   5980    96841     Red         AUTO
# 448  2001    SE   4899   151479  Yellow         AUTO
# 449  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.index=range(150)
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={1:5000})
# Out:
#       year model  price  mileage   color transmission
# 0     1887  1277   1854     7413  Yellow         AUTO
# 5000  1439  1688   1780    10926    Gray         AUTO
# 2     1955  1864   1830     7351  Silver         AUTO
# 3     2011   SEL  17809    11613    Gray         AUTO
# 4     2012    SE  17500     8367   White         AUTO
# ...    ...   ...    ...      ...     ...          ...
# 145   2006   SES   6200    95000  Silver         AUTO
# 146   2002    SE   5995    87003     Red         AUTO
# 147   2000    SE   5980    96841     Red         AUTO
# 148   2001    SE   4899   151479  Yellow         AUTO
# 149   2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={1:400,3:500})
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 400  1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 500  2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(columns={'model':'Model','color':'Color'})
# Out:
#      year Model  price  mileage   Color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
df.columns.str

# %%
df.columns.str.upper()
# Out:
# Index(['YEAR', 'MODEL', 'PRICE', 'MILEAGE', 'COLOR', 'TRANSMISSION'], dtype='object')

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.columns=df.columns.str.upper()
df
# Out:
#      YEAR MODEL  PRICE  MILEAGE   COLOR TRANSMISSION
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.columns=df.columns.str.capitalize()
df
# Out:
#      Year Model  Price  Mileage   Color Transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df
# Out:
#      Year Model  Price  Mileage   Color Transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.columns=df.columns.str.lower()
df
# Out:
#      year model  price  mileage   color transmission
# 0    1887  1277   1854     7413  Yellow         AUTO
# 1    1439  1688   1780    10926    Gray         AUTO
# 2    1955  1864   1830     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df=pd.read_csv('j:/data_science/csv/data/usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.model=='SEL'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: model, Length: 150, dtype: bool

# %%
c=df.model=='SEL'
c
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: model, Length: 150, dtype: bool

# %%
df[[1,2,3]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[107], line 1
# ----> 1 df[[1,2,3]]
#
# File F:\anaconda\Lib\site-packages\pandas\core\frame.py:4108, in DataFrame.__getitem__(self, key)
#    4106     if is_iterator(key):
#    4107         key = list(key)
# -> 4108     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4110 # take() does not accept boolean indexers
#    4111 if getattr(indexer, "dtype", None) == bool:
#
# File F:\anaconda\Lib\site-packages\pandas\core\indexes\base.py:6200, in Index._get_indexer_strict(self, key, axis_name)
#    6197 else:
#    6198     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6200 self._raise_if_missing(keyarr, indexer, axis_name)
#    6202 keyarr = self.take(indexer)
#    6203 if isinstance(key, Index):
#    6204     # GH 42790 - Preserve name from an Index
#
# ...

# %%
df[c]
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# 12   2011   SEL  16950     9388   Green         AUTO
# 16   2010   SEL  15999    19926  Silver         AUTO
# 18   2011   SEL  15992    11662    Blue         AUTO
# 19   2011   SEL  15992    32069  Silver         AUTO
# 21   2010   SEL  15980    39943   White         AUTO
# 23   2010   SEL  15889    24920   Black         AUTO
# 24   2009   SEL  15688    20019    Blue         AUTO
# 29   2009   SEL  14999    33107  Silver         AUTO
# 33   2011   SEL  14992    18948   Black         AUTO
# 35   2010   SEL  14990    33036   Black         AUTO
# ...

# %%
df[df.model=='SEL']
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# 12   2011   SEL  16950     9388   Green         AUTO
# 16   2010   SEL  15999    19926  Silver         AUTO
# 18   2011   SEL  15992    11662    Blue         AUTO
# 19   2011   SEL  15992    32069  Silver         AUTO
# 21   2010   SEL  15980    39943   White         AUTO
# 23   2010   SEL  15889    24920   Black         AUTO
# 24   2009   SEL  15688    20019    Blue         AUTO
# 29   2009   SEL  14999    33107  Silver         AUTO
# 33   2011   SEL  14992    18948   Black         AUTO
# 35   2010   SEL  14990    33036   Black         AUTO
# ...

# %%
df[~(df.model=='SEL')]
# Out:
#      year model  price  mileage   color transmission
# 4    2012    SE  17500     8367   White         AUTO
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 10   2010   SES  16995    40539   Black         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [127 rows x 6 columns]

# %%
df[ (df.model=='SEL') | (df.model=='SE')  ]
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 142  2000    SE   6980    60161   Green         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [101 rows x 6 columns]

# %%
df.model.isin(['SEL','SE'])
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146     True
# 147     True
# 148     True
# 149     True
# Name: model, Length: 150, dtype: bool

# %%
df[df.model.isin(['SEL','SE'])]
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 142  2000    SE   6980    60161   Green         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [101 rows x 6 columns]

# %%
df[ ~ (df.model.isin(['SEL','SE'])   )]
# Out:
#      year model  price  mileage   color transmission
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 10   2010   SES  16995    40539   Black         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# 13   2010   SES  16950    32058     Red         AUTO
# 15   2011   SES  15999    16368    Blue         AUTO
# 17   2010   SES  15995    36049  Silver         AUTO
# 20   2010   SES  15988    16035  Silver       MANUAL
# 28   2010   SES  15298    22029    Gray         AUTO
# 30   2010   SES  14999    36306     Red         AUTO
# 34   2009   SES  14992    24030     Red         AUTO
# 40   2010   SES  14761    44813   Black         AUTO
# 41   2010   SES  14699    36469    Gray         AUTO
# 42   2010   SES  14677    22143   Black       MANUAL
# 43   2009   SES  14549    34046  Silver         AUTO
# 45   2010   SES  14495    35894  Silver         AUTO
# 51   2010   SES  14275    35318   Black         AUTO
# ...

# %%
df.year>2010
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: year, Length: 150, dtype: bool

# %%
df[df.year>2010]
# Out:
#     year model  price  mileage   color transmission
# 0   2011   SEL  21992     7413  Yellow         AUTO
# 1   2011   SEL  20995    10926    Gray         AUTO
# 2   2011   SEL  19995     7351  Silver         AUTO
# 3   2011   SEL  17809    11613    Gray         AUTO
# 4   2012    SE  17500     8367   White         AUTO
# 6   2011   SEL  17000    27393    Blue         AUTO
# 8   2011   SES  16995    32655  Silver         AUTO
# 11  2011   SES  16992     9199  Silver         AUTO
# 12  2011   SEL  16950     9388   Green         AUTO
# 14  2011    SE  16000    15367   White         AUTO
# 15  2011   SES  15999    16368    Blue         AUTO
# 18  2011   SEL  15992    11662    Blue         AUTO
# 19  2011   SEL  15992    32069  Silver         AUTO
# 22  2011    SE  15899    36685  Silver         AUTO
# 32  2011    SE  14992     4867   Black         AUTO
# 33  2011   SEL  14992    18948   Black         AUTO
# 36  2011    SE  14989    23967   White         AUTO

# %%
df.price>17000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 145    False
# 146    False
# 147    False
# 148    False
# 149    False
# Name: price, Length: 150, dtype: bool

# %%
df[df.price>17000]
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO

# %%
#update t1  set price =price+100 where price>17000

# %%
df[df.price>17000].price=0
# Out:
# C:\Users\Malay\AppData\Local\Temp\ipykernel_3856\1619819708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[df.price>17000].price=0

# %%
df[df.price>17000]
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO

# %%
df.loc[df.price>17000,'price']=0
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926    Gray         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613    Gray         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.loc[df.color=='Gray','color']='indigo'
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.query('model in ["SES","SE"]')
# Out:
#      year model  price  mileage   color transmission
# 4    2012    SE      0     8367   White         AUTO
# 8    2011   SES  16995    32655  Silver         AUTO
# 9    2010   SES  16995    36116  Silver         AUTO
# 10   2010   SES  16995    40539   Black         AUTO
# 11   2011   SES  16992     9199  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [127 rows x 6 columns]

# %%
#rename row and column

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={0:100})
# Out:
#      year model  price  mileage   color transmission
# 100  2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={0:100},inplace=True)

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 100  2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={100:0},inplace=True)

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL      0     7413  Yellow         AUTO
# 1    2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(index={0:100,1:200})
# Out:
#      year model  price  mileage   color transmission
# 100  2011   SEL      0     7413  Yellow         AUTO
# 200  2011   SEL      0    10926  indigo         AUTO
# 2    2011   SEL      0     7351  Silver         AUTO
# 3    2011   SEL      0    11613  indigo         AUTO
# 4    2012    SE      0     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.rename(columns={'year':'YEAR','price':'new_price'})
# Out:
#      YEAR model  new_price  mileage   color transmission
# 0    2011   SEL          0     7413  Yellow         AUTO
# 1    2011   SEL          0    10926  indigo         AUTO
# 2    2011   SEL          0     7351  Silver         AUTO
# 3    2011   SEL          0    11613  indigo         AUTO
# 4    2012    SE          0     8367   White         AUTO
# ..    ...   ...        ...      ...     ...          ...
# 145  2006   SES       6200    95000  Silver         AUTO
# 146  2002    SE       5995    87003     Red         AUTO
# 147  2000    SE       5980    96841     Red         AUTO
# 148  2001    SE       4899   151479  Yellow         AUTO
# 149  2000    SE       3800   109259     Red         AUTO
#
# [150 rows x 6 columns]
