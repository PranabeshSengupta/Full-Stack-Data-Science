# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=[10,20,30,40,50,15,25,35]
plt.hist(x)
# Out:
# (array([1., 1., 1., 1., 0., 1., 1., 1., 0., 1.]),
#  array([10., 14., 18., 22., 26., 30., 34., 38., 42., 46., 50.]),
#  <BarContainer object of 10 artists>)

# %%
x=[10,20,30,40,50,15,25,35]
plt.hist(x,bins=5)
# Out:
# (array([2., 2., 1., 2., 1.]),
#  array([10., 18., 26., 34., 42., 50.]),
#  <BarContainer object of 5 artists>)

# %%
x=[1,2,3,4,7,10,15,25,100,200]
plt.hist(x)
# Out:
# (array([7., 1., 0., 0., 1., 0., 0., 0., 0., 1.]),
#  array([  1. ,  20.9,  40.8,  60.7,  80.6, 100.5, 120.4, 140.3, 160.2,
#         180.1, 200. ]),
#  <BarContainer object of 10 artists>)

# %%
x=[1,5,8,9,40,50,60,80,70,2,3,4,7,10,15,25,40,50,81,62,75,25,60,98,97,66,88100,200]
plt.hist(np.log(x))
# Out:
# (array([ 3.,  5.,  4., 12.,  3.,  0.,  0.,  0.,  0.,  1.]),
#  array([ 0.        ,  1.13862278,  2.27724556,  3.41586834,  4.55449112,
#          5.69311391,  6.83173669,  7.97035947,  9.10898225, 10.24760503,
#         11.38622781]),
#  <BarContainer object of 10 artists>)

# %%
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2abce2143e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2abce275970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2abce227d10>],
#  'medians': [<matplotlib.lines.Line2D at 0x2abccb1a720>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2abccbe5760>],
#  'means': []}
