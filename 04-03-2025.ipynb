# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
i=pd.date_range(start='1-1-2025',periods=10)
i
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
i=pd.date_range(start='1-1-2025',periods=60)
i
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10', '2025-01-11', '2025-01-12',
#                '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#                '2025-01-17', '2025-01-18', '2025-01-19', '2025-01-20',
#                '2025-01-21', '2025-01-22', '2025-01-23', '2025-01-24',
#                '2025-01-25', '2025-01-26', '2025-01-27', '2025-01-28',
#                '2025-01-29', '2025-01-30', '2025-01-31', '2025-02-01',
#                '2025-02-02', '2025-02-03', '2025-02-04', '2025-02-05',
#                '2025-02-06', '2025-02-07', '2025-02-08', '2025-02-09',
#                '2025-02-10', '2025-02-11', '2025-02-12', '2025-02-13',
#                '2025-02-14', '2025-02-15', '2025-02-16', '2025-02-17',
#                '2025-02-18', '2025-02-19', '2025-02-20', '2025-02-21',
# ...

# %%
i=pd.date_range(start='1-1-2025',periods=60,freq='ME')
i
# Out:
# DatetimeIndex(['2025-01-31', '2025-02-28', '2025-03-31', '2025-04-30',
#                '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#                '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31',
#                '2026-01-31', '2026-02-28', '2026-03-31', '2026-04-30',
#                '2026-05-31', '2026-06-30', '2026-07-31', '2026-08-31',
#                '2026-09-30', '2026-10-31', '2026-11-30', '2026-12-31',
#                '2027-01-31', '2027-02-28', '2027-03-31', '2027-04-30',
#                '2027-05-31', '2027-06-30', '2027-07-31', '2027-08-31',
#                '2027-09-30', '2027-10-31', '2027-11-30', '2027-12-31',
#                '2028-01-31', '2028-02-29', '2028-03-31', '2028-04-30',
#                '2028-05-31', '2028-06-30', '2028-07-31', '2028-08-31',
#                '2028-09-30', '2028-10-31', '2028-11-30', '2028-12-31',
#                '2029-01-31', '2029-02-28', '2029-03-31', '2029-04-30',
# ...

# %%
i=pd.date_range(start='1-1-2025',periods=20)
i
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10', '2025-01-11', '2025-01-12',
#                '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#                '2025-01-17', '2025-01-18', '2025-01-19', '2025-01-20'],
#               dtype='datetime64[ns]', freq='D')

# %%
a=np.random.randint(10,20,size=20)
df=pd.DataFrame(a,index=i)
df
# Out:
#              0
# 2025-01-01  10
# 2025-01-02  13
# 2025-01-03  18
# 2025-01-04  15
# 2025-01-05  17
# 2025-01-06  18
# 2025-01-07  15
# 2025-01-08  11
# 2025-01-09  16
# 2025-01-10  15
# 2025-01-11  15
# 2025-01-12  10
# 2025-01-13  16
# 2025-01-14  17
# 2025-01-15  11
# 2025-01-16  19
# 2025-01-17  11
# 2025-01-18  19
# 2025-01-19  10
# 2025-01-20  10

# %%
plt.plot(df[0])

# %%
i=pd.date_range(start='1-1-2025',periods=20,freq='1min')
i
# Out:
# DatetimeIndex(['2025-01-01 00:00:00', '2025-01-01 00:01:00',
#                '2025-01-01 00:02:00', '2025-01-01 00:03:00',
#                '2025-01-01 00:04:00', '2025-01-01 00:05:00',
#                '2025-01-01 00:06:00', '2025-01-01 00:07:00',
#                '2025-01-01 00:08:00', '2025-01-01 00:09:00',
#                '2025-01-01 00:10:00', '2025-01-01 00:11:00',
#                '2025-01-01 00:12:00', '2025-01-01 00:13:00',
#                '2025-01-01 00:14:00', '2025-01-01 00:15:00',
#                '2025-01-01 00:16:00', '2025-01-01 00:17:00',
#                '2025-01-01 00:18:00', '2025-01-01 00:19:00'],
#               dtype='datetime64[ns]', freq='min')

# %%
i=pd.date_range(start='1-1-2025',periods=20,freq='3min')
i
# Out:
# DatetimeIndex(['2025-01-01 00:00:00', '2025-01-01 00:03:00',
#                '2025-01-01 00:06:00', '2025-01-01 00:09:00',
#                '2025-01-01 00:12:00', '2025-01-01 00:15:00',
#                '2025-01-01 00:18:00', '2025-01-01 00:21:00',
#                '2025-01-01 00:24:00', '2025-01-01 00:27:00',
#                '2025-01-01 00:30:00', '2025-01-01 00:33:00',
#                '2025-01-01 00:36:00', '2025-01-01 00:39:00',
#                '2025-01-01 00:42:00', '2025-01-01 00:45:00',
#                '2025-01-01 00:48:00', '2025-01-01 00:51:00',
#                '2025-01-01 00:54:00', '2025-01-01 00:57:00'],
#               dtype='datetime64[ns]', freq='3min')

# %%
df
# Out:
#              0
# 2025-01-01  19
# 2025-01-02  13
# 2025-01-03  19
# 2025-01-04  19
# 2025-01-05  18
# 2025-01-06  16
# 2025-01-07  10
# 2025-01-08  14
# 2025-01-09  15
# 2025-01-10  10
# 2025-01-11  11
# 2025-01-12  14
# 2025-01-13  15
# 2025-01-14  18
# 2025-01-15  17
# 2025-01-16  19
# 2025-01-17  12
# 2025-01-18  10
# 2025-01-19  14
# 2025-01-20  17

# %%
i=pd.date_range(start='1-1-2025',periods=60,freq='D')
i
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10', '2025-01-11', '2025-01-12',
#                '2025-01-13', '2025-01-14', '2025-01-15', '2025-01-16',
#                '2025-01-17', '2025-01-18', '2025-01-19', '2025-01-20',
#                '2025-01-21', '2025-01-22', '2025-01-23', '2025-01-24',
#                '2025-01-25', '2025-01-26', '2025-01-27', '2025-01-28',
#                '2025-01-29', '2025-01-30', '2025-01-31', '2025-02-01',
#                '2025-02-02', '2025-02-03', '2025-02-04', '2025-02-05',
#                '2025-02-06', '2025-02-07', '2025-02-08', '2025-02-09',
#                '2025-02-10', '2025-02-11', '2025-02-12', '2025-02-13',
#                '2025-02-14', '2025-02-15', '2025-02-16', '2025-02-17',
#                '2025-02-18', '2025-02-19', '2025-02-20', '2025-02-21',
# ...

# %%
a=np.random.randint(10,20,size=60)
df=pd.DataFrame(a,index=i)
df
# Out:
#              0
# 2025-01-01  10
# 2025-01-02  15
# 2025-01-03  18
# 2025-01-04  19
# 2025-01-05  19
# 2025-01-06  19
# 2025-01-07  13
# 2025-01-08  18
# 2025-01-09  10
# 2025-01-10  13
# 2025-01-11  10
# 2025-01-12  12
# 2025-01-13  10
# 2025-01-14  16
# 2025-01-15  17
# 2025-01-16  18
# 2025-01-17  13
# 2025-01-18  11
# 2025-01-19  19
# 2025-01-20  17
# 2025-01-21  16
# 2025-01-22  18
# 2025-01-23  17
# 2025-01-24  15
# 2025-01-25  14
# 2025-01-26  10
# 2025-01-27  19
# 2025-01-28  11
# 2025-01-29  14
# 2025-01-30  14
# 2025-01-31  16
# 2025-02-01  10
# 2025-02-02  12
# 2025-02-03  16
# 2025-02-04  10
# 2025-02-05  13
# 2025-02-06  12
# 2025-02-07  13
# 2025-02-08  19
# 2025-02-09  15
# 2025-02-10  12
# 2025-02-11  16
# 2025-02-12  17
# 2025-02-13  13
# 2025-02-14  16
# 2025-02-15  14
# 2025-02-16  17
# 2025-02-17  10
# 2025-02-18  11
# 2025-02-19  15
# 2025-02-20  17
# 2025-02-21  17
# 2025-02-22  13
# 2025-02-23  14
# 2025-02-24  18
# 2025-02-25  17
# 2025-02-26  18
# ...

# %%
df.resample('ME')

# %%
df.resample('ME')[0].sum()
# Out:
# 2025-01-31    461
# 2025-02-28    402
# 2025-03-31     16
# Freq: ME, Name: 0, dtype: int32

# %%
df.resample('YE')[0].sum()
# Out:
# 2025-12-31    879
# Freq: YE-DEC, Name: 0, dtype: int32

# %%
df=pd.read_csv('ETH.csv')
df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.dtypes
# Out:
# Date       object
# Symbol     object
# Open      float64
# High      float64
# Low       float64
# Close     float64
# Volume    float64
# dtype: object

# %%
pd.to_datetime(df.Date,format='%Y-%m-%d %I-%p')
# Out:
# 0       2020-03-13 20:00:00
# 1       2020-03-13 19:00:00
# 2       2020-03-13 18:00:00
# 3       2020-03-13 17:00:00
# 4       2020-03-13 16:00:00
#                 ...
# 23669   2017-07-01 15:00:00
# 23670   2017-07-01 14:00:00
# 23671   2017-07-01 13:00:00
# 23672   2017-07-01 12:00:00
# 23673   2017-07-01 11:00:00
# Name: Date, Length: 23674, dtype: datetime64[ns]

# %%
df.Date=pd.to_datetime(df.Date,format='%Y-%m-%d %I-%p')
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.dtypes
# Out:
# Date      datetime64[ns]
# Symbol            object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# dtype: object

# %%
df.Date.dt.month
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
#         ..
# 23669    7
# 23670    7
# 23671    7
# 23672    7
# 23673    7
# Name: Date, Length: 23674, dtype: int32

# %%
df.Date.dt.dayofweek
# Out:
# 0        4
# 1        4
# 2        4
# 3        4
# 4        4
#         ..
# 23669    5
# 23670    5
# 23671    5
# 23672    5
# 23673    5
# Name: Date, Length: 23674, dtype: int32

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.set_index(df.Date)
# Out:
#                                    Date  Symbol    Open    High     Low  \
# Date
# 2020-03-13 20:00:00 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87
# 2020-03-13 19:00:00 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10
# 2020-03-13 18:00:00 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50
# 2020-03-13 17:00:00 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63
# 2020-03-13 16:00:00 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17
# ...                                 ...     ...     ...     ...     ...
# 2017-07-01 15:00:00 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00
# 2017-07-01 14:00:00 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00
# 2017-07-01 13:00:00 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00
# 2017-07-01 12:00:00 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00
# 2017-07-01 11:00:00 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10
#
#                       Close      Volume
# Date
# 2020-03-13 20:00:00  128.71  1940673.93
# ...

# %%
df.set_index(df.Date,inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df.resample('ME')['Open'].sum()
# Out:
# Date
# 2017-07-31    161347.20
# 2017-08-31    221904.41
# 2017-09-30    215032.66
# 2017-10-31    227398.09
# 2017-11-30    255939.29
# 2017-12-31    468336.81
# 2018-01-31    806163.05
# 2018-02-28    586305.07
# 2018-03-31    468955.48
# 2018-04-30    371304.45
# 2018-05-31    503280.22
# 2018-06-30    374375.74
# 2018-07-31    343629.27
# 2018-08-31    240474.71
# 2018-09-30    163379.21
# 2018-10-31    154591.68
# 2018-11-30    121307.30
# 2018-12-31     79810.66
# 2019-01-31     94561.53
# 2019-02-28     83864.68
# 2019-03-31    100746.70
# 2019-04-30    118731.90
# 2019-05-31    162018.48
# 2019-06-30    197097.25
# 2019-07-31    184993.59
# 2019-08-31    148636.25
# 2019-09-30    133280.06
# 2019-10-31    132612.83
# 2019-11-30    124634.83
# 2019-12-31    102211.67
# 2020-01-31    115332.59
# 2020-02-29    165617.09
# 2020-03-31     64597.91
# Freq: ME, Name: Open, dtype: float64

# %%
plt.plot(df.resample('ME')['Open'].sum())

# %%
df.resample('YE')['Open'].sum()
# Out:
# Date
# 2017-12-31    1549958.46
# 2018-12-31    4213576.84
# 2019-12-31    1583389.77
# 2020-12-31     345547.59
# Freq: YE-DEC, Name: Open, dtype: float64

# %%
plt.plot(df.resample('YE')['Open'].sum())

# %%
df.sample(5)
# Out:
#                                    Date  Symbol     Open     High      Low  \
# Date
# 2019-12-02 13:00:00 2019-12-02 13:00:00  ETHUSD   149.15   149.75   148.79
# 2018-01-08 06:00:00 2018-01-08 06:00:00  ETHUSD  1192.80  1225.00  1185.06
# 2019-04-26 14:00:00 2019-04-26 14:00:00  ETHUSD   152.38   152.71   151.63
# 2019-09-17 05:00:00 2019-09-17 05:00:00  ETHUSD   196.82   199.00   196.82
# 2018-08-17 00:00:00 2018-08-17 00:00:00  ETHUSD   286.67   291.75   285.42
#
#                        Close      Volume
# Date
# 2019-12-02 13:00:00   149.48   173323.98
# 2018-01-08 06:00:00  1224.99  9698846.79
# 2019-04-26 14:00:00   152.43  1614289.25
# 2019-09-17 05:00:00   198.27   552378.33
# 2018-08-17 00:00:00   291.74  1415146.80

# %%
df
# Out:
#                                    Date  Symbol    Open    High     Low  \
# Date
# 2020-03-13 20:00:00 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87
# 2020-03-13 19:00:00 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10
# 2020-03-13 18:00:00 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50
# 2020-03-13 17:00:00 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63
# 2020-03-13 16:00:00 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17
# ...                                 ...     ...     ...     ...     ...
# 2017-07-01 15:00:00 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00
# 2017-07-01 14:00:00 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00
# 2017-07-01 13:00:00 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00
# 2017-07-01 12:00:00 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00
# 2017-07-01 11:00:00 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10
#
#                       Close      Volume
# Date
# 2020-03-13 20:00:00  128.71  1940673.93
# ...

# %%
df.reset_index()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10984\1473210594.py in ?()
# ----> 1 df.reset_index()
#
# F:\anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6468                     level_values = algorithms.take(
#    6469                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#    6475                     level_values,
#
# F:\anaconda\Lib\site-packages\pandas\core\frame.py in ?(self, loc, column, value, allow_duplicates)
#    5154                 "'self.flags.allows_duplicate_labels' is False."
#    5155             )
# ...

# %%
df=pd.read_csv('j:/data_science/csv/data/fruits.csv')
df
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
df.set_index('color',inplace=True)

# %%
df
# Out:
#                  sphericity  weight   label
# color
# Orange                0.947     120  Orange
# Orange                0.917     125  Orange
# Orange                0.923     110  Orange
# Orange                0.916     123  Orange
# Orange                0.943     124  Orange
# Orange                0.911     130  Orange
# Orange                0.903     135  Orange
# Orange                0.918     105  Orange
# Orange                0.914     132  Orange
# Orange                0.936     127  Orange
# Greenish yellow       0.829     133  Orange
# Greenish yellow       0.875     134  Orange
# Greenish yellow       0.859     110  Orange
# Green                 0.849     119  Orange
# Green                 0.868     106  Orange
# Greenish yellow       0.884     113  Orange
# Greenish yellow       0.872     108  Orange
# Greenish yellow       0.823     132  Orange
# Green                 0.853     119  Orange
# Green                 0.808     143  Orange
# ...

# %%
df.reset_index()
# Out:
#               color  sphericity  weight   label
# 0            Orange       0.947     120  Orange
# 1            Orange       0.917     125  Orange
# 2            Orange       0.923     110  Orange
# 3            Orange       0.916     123  Orange
# 4            Orange       0.943     124  Orange
# 5            Orange       0.911     130  Orange
# 6            Orange       0.903     135  Orange
# 7            Orange       0.918     105  Orange
# 8            Orange       0.914     132  Orange
# 9            Orange       0.936     127  Orange
# 10  Greenish yellow       0.829     133  Orange
# 11  Greenish yellow       0.875     134  Orange
# 12  Greenish yellow       0.859     110  Orange
# 13            Green       0.849     119  Orange
# 14            Green       0.868     106  Orange
# 15  Greenish yellow       0.884     113  Orange
# 16  Greenish yellow       0.872     108  Orange
# 17  Greenish yellow       0.823     132  Orange
# 18            Green       0.853     119  Orange
# ...

# %%
df=pd.read_csv('j:/data_science/csv/data/usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.set_index('model',inplace=True)

# %%
df
# Out:
#        year  price  mileage   color transmission
# model
# SEL    2011  21992     7413  Yellow         AUTO
# SEL    2011  20995    10926    Gray         AUTO
# SEL    2011  19995     7351  Silver         AUTO
# SEL    2011  17809    11613    Gray         AUTO
# SE     2012  17500     8367   White         AUTO
# ...     ...    ...      ...     ...          ...
# SES    2006   6200    95000  Silver         AUTO
# SE     2002   5995    87003     Red         AUTO
# SE     2000   5980    96841     Red         AUTO
# SE     2001   4899   151479  Yellow         AUTO
# SE     2000   3800   109259     Red         AUTO
#
# [150 rows x 5 columns]

# %%
df['SE':]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[113], line 1
# ----> 1 df['SE':]
#
# File F:\anaconda\Lib\site-packages\pandas\core\frame.py:4085, in DataFrame.__getitem__(self, key)
#    4083 # Do we have a slicer (on rows)?
#    4084 if isinstance(key, slice):
# -> 4085     return self._getitem_slice(key)
#    4087 # Do we have a (boolean) DataFrame?
#    4088 if isinstance(key, DataFrame):
#
# File F:\anaconda\Lib\site-packages\pandas\core\generic.py:4349, in NDFrame._getitem_slice(self, key)
#    4344 """
#    4345 __getitem__ for the case where the key is a slice object.
#    4346 """
#    4347 # _convert_slice_indexer to determine if this slice is positional
#    4348 #  or label based, and if the latter, convert to positional
# -> 4349 slobj = self.index._convert_slice_indexer(key, kind="getitem")
#    4350 if isinstance(slobj, np.ndarray):
# ...

# %%
df.sort_index(inplace=True)

# %%
df
# Out:
#        year  price  mileage   color transmission
# model
# SE     2000   3800   109259     Red         AUTO
# SE     2010  13995    20278   Black       MANUAL
# SE     2010  13995    13541  Silver         AUTO
# SE     2010  13997    15167   Black       MANUAL
# SE     2009  13999    23785     Red         AUTO
# ...     ...    ...      ...     ...          ...
# SES    2005  10995    69415    Blue         AUTO
# SES    2010  15298    22029    Gray         AUTO
# SES    2009  13425    64055   Black         AUTO
# SES    2009  14549    34046  Silver         AUTO
# SES    2010  13599    33302     Red         AUTO
#
# [150 rows x 5 columns]

# %%
df['SE':'SEL']
# Out:
#        year  price  mileage   color transmission
# model
# SE     2000   3800   109259     Red         AUTO
# SE     2010  13995    20278   Black       MANUAL
# SE     2010  13995    13541  Silver         AUTO
# SE     2010  13997    15167   Black       MANUAL
# SE     2009  13999    23785     Red         AUTO
# ...     ...    ...      ...     ...          ...
# SEL    2009  13663    27528  Silver         AUTO
# SEL    2010  13687    35574    Gray         AUTO
# SEL    2011  20995    10926    Gray         AUTO
# SEL    2011  17000    27393    Blue         AUTO
# SEL    2011  19995     7351  Silver         AUTO
#
# [101 rows x 5 columns]

# %%
df.reset_index(inplace=True)

# %%
df.sample(5)
# Out:
#     model  year  price  mileage   color transmission
# 94    SEL  2011  17809    11613    Gray         AUTO
# 96    SEL  2009  13663    27528  Silver         AUTO
# 32     SE  2010  13950    31414   Black         AUTO
# 146   SES  2010  15298    22029    Gray         AUTO
# 31     SE  2010  13950    37185    Blue         AUTO

# %%
#line plot

# %%
x=[2,4,6]
y=[8,6,4]
plt.plot(x,y)

# %%
plt.plot(x)

# %%
#sin graph
#cos graph

# %%
x=np.linspace(0,2*np.pi)
y=np.sin(x)
y2=np.cos(x)

plt.plot(x,y,x,y2)

#figure object
#axes object

# %%
plt.plot(x,y2)

# %%
x=[2,4,6]
y=[8,6,4]
plt.plot(x,y,marker='D',c='#567ed6')

# %%
df.sample(4)
# Out:
#    model  year  price  mileage  color transmission
# 69    SE  2008  11450    85229    Red       MANUAL
# 1     SE  2010  13995    20278  Black       MANUAL
# 67    SE  2008  11754    38286  Black         AUTO
# 13    SE  2010  14499    32703    Red         AUTO

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.set_index('Date',inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df.resample('YE')

# %%
df.resample('YE')['High'].sum()
# Out:
# Date
# 2017-12-31    1562784.98
# 2018-12-31    4245740.31
# 2019-12-31    1592275.52
# 2020-12-31     348104.42
# Freq: YE-DEC, Name: High, dtype: float64

# %%
df.resample('YE')['High'].sum().plot.bar()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('D')['High'].sum()
# Out:
# Date
# 2017-07-01    3493.08
# 2017-07-02    6538.53
# 2017-07-03    6738.58
# 2017-07-04    6672.82
# 2017-07-05    6410.88
#                ...
# 2020-03-09    4879.48
# 2020-03-10    4875.72
# 2020-03-11    4744.42
# 2020-03-12    3816.15
# 2020-03-13    2741.83
# Freq: D, Name: High, Length: 987, dtype: float64
