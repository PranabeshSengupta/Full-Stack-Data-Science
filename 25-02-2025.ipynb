# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
d={'tv':[5000],'printer':[6000],'monitor':[7000]}

# %%
pd.DataFrame(d)
# Out:
#      tv  printer  monitor
# 0  5000     6000     7000

# %%
d={'tv':5000,'printer':6000,'monitor':7000}

# %%
pd.DataFrame(d,index=['product'])
# Out:
#            tv  printer  monitor
# product  5000     6000     7000

# %%
d={'tv':[5000,5500],'printer':[6000,6600],'monitor':[7000,8800]}
pd.DataFrame(d,index=['products1','products2'])
# Out:
#              tv  printer  monitor
# products1  5000     6000     7000
# products2  5500     6600     8800

# %%
#from 2D array

# %%
a=np.random.randint(10,20,size=(5,4))
a
# Out:
# array([[19, 13, 12, 14],
#        [17, 10, 16, 11],
#        [19, 12, 17, 12],
#        [15, 14, 17, 12],
#        [16, 18, 17, 14]])

# %%
pd.DataFrame(a)
# Out:
#     0   1   2   3
# 0  19  13  12  14
# 1  17  10  16  11
# 2  19  12  17  12
# 3  15  14  17  12
# 4  16  18  17  14

# %%
#from CSV file [ comma separated values ]

# %%
df=pd.read_csv('usedcars.csv',header=None)
df
# Out:
#         0      1      2        3       4             5
# 0    year  model  price  mileage   color  transmission
# 1    2011    SEL  21992     7413  Yellow          AUTO
# 2    2011    SEL  20995    10926    Gray          AUTO
# 3    2011    SEL  19995     7351  Silver          AUTO
# 4    2011    SEL  17809    11613    Gray          AUTO
# ..    ...    ...    ...      ...     ...           ...
# 146  2006    SES   6200    95000  Silver          AUTO
# 147  2002     SE   5995    87003     Red          AUTO
# 148  2000     SE   5980    96841     Red          AUTO
# 149  2001     SE   4899   151479  Yellow          AUTO
# 150  2000     SE   3800   109259     Red          AUTO
#
# [151 rows x 6 columns]

# %%
df=pd.read_csv('usedcars.csv',names=list('abcdef'))
df
# Out:
#         a      b      c        d       e             f
# 0    year  model  price  mileage   color  transmission
# 1    2011    SEL  21992     7413  Yellow          AUTO
# 2    2011    SEL  20995    10926    Gray          AUTO
# 3    2011    SEL  19995     7351  Silver          AUTO
# 4    2011    SEL  17809    11613    Gray          AUTO
# ..    ...    ...    ...      ...     ...           ...
# 146  2006    SES   6200    95000  Silver          AUTO
# 147  2002     SE   5995    87003     Red          AUTO
# 148  2000     SE   5980    96841     Red          AUTO
# 149  2001     SE   4899   151479  Yellow          AUTO
# 150  2000     SE   3800   109259     Red          AUTO
#
# [151 rows x 6 columns]

# %%
df=pd.read_csv('usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df=pd.read_csv('usedcars.csv',names=list('abcdef'),header=0)
df
# Out:
#         a    b      c       d       e     f
# 0    2011  SEL  21992    7413  Yellow  AUTO
# 1    2011  SEL  20995   10926    Gray  AUTO
# 2    2011  SEL  19995    7351  Silver  AUTO
# 3    2011  SEL  17809   11613    Gray  AUTO
# 4    2012   SE  17500    8367   White  AUTO
# ..    ...  ...    ...     ...     ...   ...
# 145  2006  SES   6200   95000  Silver  AUTO
# 146  2002   SE   5995   87003     Red  AUTO
# 147  2000   SE   5980   96841     Red  AUTO
# 148  2001   SE   4899  151479  Yellow  AUTO
# 149  2000   SE   3800  109259     Red  AUTO
#
# [150 rows x 6 columns]

# %%
df=pd.read_csv('usedcars.csv')
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.shape
# Out:
# (150, 6)

# %%
df.size
# Out:
# 900

# %%
df.ndim
# Out:
# 2

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
#df.columns[0]='product'      #Index does not support mutable operations

# %%
df.values
# Out:
# array([[2011, 'SEL', 21992, 7413, 'Yellow', 'AUTO'],
#        [2011, 'SEL', 20995, 10926, 'Gray', 'AUTO'],
#        [2011, 'SEL', 19995, 7351, 'Silver', 'AUTO'],
#        [2011, 'SEL', 17809, 11613, 'Gray', 'AUTO'],
#        [2012, 'SE', 17500, 8367, 'White', 'AUTO'],
#        [2010, 'SEL', 17495, 25125, 'Silver', 'AUTO'],
#        [2011, 'SEL', 17000, 27393, 'Blue', 'AUTO'],
#        [2010, 'SEL', 16995, 21026, 'Silver', 'AUTO'],
#        [2011, 'SES', 16995, 32655, 'Silver', 'AUTO'],
#        [2010, 'SES', 16995, 36116, 'Silver', 'AUTO'],
#        [2010, 'SES', 16995, 40539, 'Black', 'AUTO'],
#        [2011, 'SES', 16992, 9199, 'Silver', 'AUTO'],
#        [2011, 'SEL', 16950, 9388, 'Green', 'AUTO'],
#        [2010, 'SES', 16950, 32058, 'Red', 'AUTO'],
#        [2011, 'SE', 16000, 15367, 'White', 'AUTO'],
#        [2011, 'SES', 15999, 16368, 'Blue', 'AUTO'],
#        [2010, 'SEL', 15999, 19926, 'Silver', 'AUTO'],
#        [2010, 'SES', 15995, 36049, 'Silver', 'AUTO'],
# ...

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.head()
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO

# %%
df.head(3)
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO

# %%
df.head(10)
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 5  2010   SEL  17495    25125  Silver         AUTO
# 6  2011   SEL  17000    27393    Blue         AUTO
# 7  2010   SEL  16995    21026  Silver         AUTO
# 8  2011   SES  16995    32655  Silver         AUTO
# 9  2010   SES  16995    36116  Silver         AUTO

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.head(-3)
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 142  2000    SE   6980    60161   Green         AUTO
# 143  2004   SES   6980   101130    Gray         AUTO
# 144  2004   SES   6950   119720   Black         AUTO
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
#
# [147 rows x 6 columns]

# %%
df.tail()
# Out:
#      year model  price  mileage   color transmission
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO

# %%
df.tail(3)
# Out:
#      year model  price  mileage   color transmission
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
df.tail(-3)
# Out:
#      year model  price  mileage   color transmission
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# 5    2010   SEL  17495    25125  Silver         AUTO
# 6    2011   SEL  17000    27393    Blue         AUTO
# 7    2010   SEL  16995    21026  Silver         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [147 rows x 6 columns]

# %%
df
# Out:
#      year model  price  mileage   color transmission
# 0    2011   SEL  21992     7413  Yellow         AUTO
# 1    2011   SEL  20995    10926    Gray         AUTO
# 2    2011   SEL  19995     7351  Silver         AUTO
# 3    2011   SEL  17809    11613    Gray         AUTO
# 4    2012    SE  17500     8367   White         AUTO
# ..    ...   ...    ...      ...     ...          ...
# 145  2006   SES   6200    95000  Silver         AUTO
# 146  2002    SE   5995    87003     Red         AUTO
# 147  2000    SE   5980    96841     Red         AUTO
# 148  2001    SE   4899   151479  Yellow         AUTO
# 149  2000    SE   3800   109259     Red         AUTO
#
# [150 rows x 6 columns]

# %%
#df[0] # it gives a keyerror

# %%
df['year']
# Out:
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2012
#        ...
# 145    2006
# 146    2002
# 147    2000
# 148    2001
# 149    2000
# Name: year, Length: 150, dtype: int64

# %%
type(df['year'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[  ['year']  ]
# Out:
#      year
# 0    2011
# 1    2011
# 2    2011
# 3    2011
# 4    2012
# ..    ...
# 145  2006
# 146  2002
# 147  2000
# 148  2001
# 149  2000
#
# [150 rows x 1 columns]

# %%
type(df[  ['year']  ] )
# Out:
# pandas.core.frame.DataFrame

# %%
df[ ['price','year']     ]
# Out:
#      price  year
# 0    21992  2011
# 1    20995  2011
# 2    19995  2011
# 3    17809  2011
# 4    17500  2012
# ..     ...   ...
# 145   6200  2006
# 146   5995  2002
# 147   5980  2000
# 148   4899  2001
# 149   3800  2000
#
# [150 rows x 2 columns]

# %%
#df[ [1,2] ] #None of [Index([1, 2], dtype='int32')] are in the [columns]"

# %%
df[ 1:4 ]  # slicing is possible(row)
# Out:
#    year model  price  mileage   color transmission
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO

# %%
df.year        #it will return series
# Out:
# 0      2011
# 1      2011
# 2      2011
# 3      2011
# 4      2012
#        ...
# 145    2006
# 146    2002
# 147    2000
# 148    2001
# 149    2000
# Name: year, Length: 150, dtype: int64

# %%
df.model
# Out:
# 0      SEL
# 1      SEL
# 2      SEL
# 3      SEL
# 4       SE
#       ...
# 145    SES
# 146     SE
# 147     SE
# 148     SE
# 149     SE
# Name: model, Length: 150, dtype: object

# %%
df.columns
# Out:
# Index(['year', 'model', 'price', 'mileage', 'color', 'transmission'], dtype='object')

# %%
df['model']
# Out:
# 0      SEL
# 1      SEL
# 2      SEL
# 3      SEL
# 4       SE
#       ...
# 145    SES
# 146     SE
# 147     SE
# 148     SE
# 149     SE
# Name: model, Length: 150, dtype: object

# %%
df.iloc[0]   #iloc=>"it will used for integer location"
# Out:
# year              2011
# model              SEL
# price            21992
# mileage           7413
# color           Yellow
# transmission      AUTO
# Name: 0, dtype: object

# %%
type(df.iloc[0])
# Out:
# pandas.core.series.Series

# %%
df.iloc[0]['model'] #now we can easily access ,because now it is a series
# Out:
# 'SEL'

# %%
df.iloc[0][['model','year']]
# Out:
# model     SEL
# year     2011
# Name: 0, dtype: object

# %%
df.iloc[0]['year':'price']
# Out:
# year      2011
# model      SEL
# price    21992
# Name: 0, dtype: object

# %%
df.iloc[:3]
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO

# %%
df.loc[:3] #in location upper bound
# Out:
#    year model  price  mileage   color transmission
# 0  2011   SEL  21992     7413  Yellow         AUTO
# 1  2011   SEL  20995    10926    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO

# %%
df.loc[1]
# Out:
# year             2011
# model             SEL
# price           20995
# mileage         10926
# color            Gray
# transmission     AUTO
# Name: 1, dtype: object

# %%
df.iloc[[1,5,10]]
# Out:
#     year model  price  mileage   color transmission
# 1   2011   SEL  20995    10926    Gray         AUTO
# 5   2010   SEL  17495    25125  Silver         AUTO
# 10  2010   SES  16995    40539   Black         AUTO

# %%
df.iloc[:,5:1:-1]
# Out:
#     transmission   color  mileage  price
# 0           AUTO  Yellow     7413  21992
# 1           AUTO    Gray    10926  20995
# 2           AUTO  Silver     7351  19995
# 3           AUTO    Gray    11613  17809
# 4           AUTO   White     8367  17500
# ..           ...     ...      ...    ...
# 145         AUTO  Silver    95000   6200
# 146         AUTO     Red    87003   5995
# 147         AUTO     Red    96841   5980
# 148         AUTO  Yellow   151479   4899
# 149         AUTO     Red   109259   3800
#
# [150 rows x 4 columns]

# %%
df.iloc[5:1:-1]
# Out:
#    year model  price  mileage   color transmission
# 5  2010   SEL  17495    25125  Silver         AUTO
# 4  2012    SE  17500     8367   White         AUTO
# 3  2011   SEL  17809    11613    Gray         AUTO
# 2  2011   SEL  19995     7351  Silver         AUTO

# %%
df.loc[1:4,'year']
# Out:
# 1    2011
# 2    2011
# 3    2011
# 4    2012
# Name: year, dtype: int64

# %%
df.loc[:,'year':'price']
# Out:
#      year model  price
# 0    2011   SEL  21992
# 1    2011   SEL  20995
# 2    2011   SEL  19995
# 3    2011   SEL  17809
# 4    2012    SE  17500
# ..    ...   ...    ...
# 145  2006   SES   6200
# 146  2002    SE   5995
# 147  2000    SE   5980
# 148  2001    SE   4899
# 149  2000    SE   3800
#
# [150 rows x 3 columns]

# %%
df.loc[:,'price':'year':-1]
# Out:
#      price model  year
# 0    21992   SEL  2011
# 1    20995   SEL  2011
# 2    19995   SEL  2011
# 3    17809   SEL  2011
# 4    17500    SE  2012
# ..     ...   ...   ...
# 145   6200   SES  2006
# 146   5995    SE  2002
# 147   5980    SE  2000
# 148   4899    SE  2001
# 149   3800    SE  2000
#
# [150 rows x 3 columns]
